# %% [markdown]
# # Specific Heat

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import json
import glob
import scipy.stats as stats
import pandas as pd

# %%
sns.set()

# %%
data_root = '../data/entropy-order-convolved/'
fig_root="../figures/"
# os.listdir(data_root)

# %%
M=7
m=10
classname="BA_NetworkPercolationExplosive_v7"
signature="{}_N_*_m_10_M_{}_entropy-order_*fast.txt".format(classname,M)

# %%
files=glob.glob(data_root + signature)

# %%
signature
# Out:
# 'BA_NetworkPercolationExplosive_v7_N_*_m_10_M_7_entropy-order_*fast.txt'

# %%
files
# Out:
# ['../data/entropy-order-convolved/BA_NetworkPercolationExplosive_v7_N_1200000_m_10_M_7_entropy-order_2019_avg.txt_convoluted_1times_fast.txt',
#  '../data/entropy-order-convolved/BA_NetworkPercolationExplosive_v7_N_600000_m_10_M_7_entropy-order_2019_avg.txt_convoluted_1times_fast.txt',
#  '../data/entropy-order-convolved/BA_NetworkPercolationExplosive_v7_N_1000000_m_10_M_7_entropy-order_2019_avg.txt_convoluted_1times_fast.txt',
#  '../data/entropy-order-convolved/BA_NetworkPercolationExplosive_v7_N_400000_m_10_M_7_entropy-order_2019_avg.txt_convoluted_1times_fast.txt',
#  '../data/entropy-order-convolved/BA_NetworkPercolationExplosive_v7_N_800000_m_10_M_7_entropy-order_2019_avg.txt_convoluted_1times_fast.txt']

# %% [markdown]
# ### checking ensemble size

# %%
print("Ensemble sizes")
for file in files:
    with open(file) as f:
        line=f.readline()
        head=json.loads(line[1:])
        print("N=", head['N'], "  En=", head['En'])
# Out:
# Ensemble sizes
# N= 1200000   En= 20000
# N= 600000   En= 20000
# N= 1000000   En= 20000
# N= 400000   En= 20000
# N= 800000   En= 20000

# %%
def find_specific_heat(t, H, N):
#     C = -t[1:]*np.diff(H)/np.diff(t)  # noisy data
    C = -(1-t[1:])*np.diff(H)*N
#     print(1/np.diff(t)[0])
    
#     print(np.diff(t)[0])
#     print(np.diff(t)[1234])
#     print(np.diff(t)[-1])
    print(N)
    return C

def find_susceptibility(t, P, N):
    sus=np.diff(P)*N
    return sus

# %%
tc=0.72775

# %% [markdown]
# ## Load data from file

# %%
min_limit=0.98
max_limit=1.0

# %%
data=dict()
for file in files:
    with open(file) as f:
        line=f.readline()
        head=json.loads(line[1:])
        N=int(head['N'])
        M=int(head['M'])
        m=int(head['m'])
    X = np.loadtxt(file)
    t=X[:,0]
    index=(t > min_limit) & (t < max_limit)
    data[N] = X[index]

# %%
for N in data.keys():
#     print(data[N].shape)
    t, H, P = data[N].T
    X = find_specific_heat(t, H, N)
    plt.plot(t[1:], X, label='N={}k'.format(N//1000))
    pass
plt.legend()
# plt.xlim([0.723, 0.735])
filename=fig_root + classname + "specific_heat_m{}_M{}".format(m, M)
plt.savefig(filename)
# Out:
# 1200000
# 600000
# 1000000
# 400000
# 800000

# %%
critical = []
for N in data.keys():
#     print(data[N].shape)
    t, H, P = data[N].T

#     sns.distplot(np.diff(t), label="N={}k".format(N//1000))
    
    X = find_specific_heat(t, H, N)
    i = np.argmax(X)
    
    critical.append([N, t[i], X[i]])
    plt.plot(t[1:], X, label='N={}k'.format(N//1000))
    plt.plot(t[i], X[i], 'o')
    
    pass
plt.legend()
# plt.xlim([0.723, 0.735])
print(critical)
# Out:
# 1200000
# 600000
# 1000000
# 400000
# 800000
# [[1200000, 0.991187, 35.210476669198144], [600000, 0.991072, 23.873579653201247], [1000000, 0.991164, 31.775828474999514], [400000, 0.99096, 19.045517105600425], [800000, 0.991131, 28.0483205184012]]

# %%
def find_exponent(X):
    X=np.array(X)
    print(X.shape)
    plt.plot(np.log(X[:,0]), np.log(X[:,2]), 'o')
    regress = stats.linregress(np.log(X[:,0]), np.log(X[:,2]))
    print(regress)
    y = regress[0] * np.log(X[:,0]) + regress[1]
    plt.plot(np.log(X[:,0]), y)
    return regress

# %%
regress = find_exponent(critical)
print("alpha/nu = ", regress[0])
# Out:
# (5, 3)
# LinregressResult(slope=0.5592868253232689, intercept=-4.267916831966703, rvalue=0.9999986513522504, pvalue=1.88010267621363e-09, stderr=0.0005303208045644135)
# alpha/nu =  0.5592868253232689

# %% [markdown]
# ### It is evident that increasing system size gets you closer to the critical point
#
# It flows the relation
#
# $(t(N)-t_c(\infty)) N ^{1/\nu} = const $
#
# $(t(N)-t_c) \sim N ^{-1/\nu}$
#
# $(t(N)-t_c(\infty)) \sim N^{-1/\nu}$
#
# In the limit $N\rightarrow \infty$, $t(N) = t_c(\infty)$
#
# If $1/\nu$ is known then finding $t_c$ is very easy.

# %%
def find_tc(X, one_by_nu):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))
    X=np.array(X)
    
    axs[0].plot(X[:,0], X[:,1], 'o')
    x = X[:,0]**(-one_by_nu)
    y = X[:,1]
    print(X.shape)
    axs[1].plot(x, y, 'o')
    regress = stats.linregress(x, y)
    print(regress)
    y = regress[0] * x + regress[1]
    axs[1].plot(x, y)

# %%
one_by_nu = 0.5037072777685714
one_by_nu = 0.51
one_by_nu = 0.5094789034354745
find_tc(critical, one_by_nu)
# Out:
# (5, 3)
# LinregressResult(slope=-0.3807453500303318, intercept=0.9914985291430507, rvalue=-0.9973315965271814, pvalue=0.00016540064393941425, stderr=0.01609108160404468)

# %%
tc = 0.9845506554594833

# %% [markdown]
# #### Data Collapse
#
# Read exponents from a file
# so that I don't have to type it every time

# %%
filename = "BA_explosive_exponents"
df = pd.read_csv(filename)
df.index = df['M']

tc = df['tc'][M]
one_by_nu = df['one_by_nu'][M]
alpha_by_nu = df['alpha_by_nu'][M]

print(M)
print(tc)
print(one_by_nu)
print(alpha_by_nu)
# print(df)
# Out:
# 7
# 0.9914981154465992
# 0.5094789034354745
# 0.5592868253232689
#      M        tc  one_by_nu  alpha_by_nu  beta_by_nu  gamma_by_nu
# M
# 2    2  0.727270   0.513875     0.514096    0.062249     0.468283
# 3    3  0.884769   0.514780     0.558321    0.015210     0.490704
# 4    4  0.944485   0.513591     0.570172    0.005178     0.499559
# 5    5  0.971252   0.512185     0.570930    0.002189     0.501066
# 6    6  0.984473   0.510556     0.567879    0.001097     0.501938
# 7    7  0.991498   0.509479     0.559287    0.000000     0.502215
# 8    8  0.000000   0.000000     0.000000    0.000000     0.000000
# 9    9  0.000000   0.000000     0.000000    0.000000     0.000000
# 10  10  0.000000   0.000000     0.000000    0.000000     0.000000

# %%
# tc -= 0.0001
# one_by_nu += 0.002
plt.figure(figsize=(8, 5))
for N in data.keys():
#     print(data[N].shape)
    t, H, P = data[N].T
    X = find_specific_heat(t, H, N)
    x=(t-tc)*N**(one_by_nu)
    y=X*N**(-alpha_by_nu)
    plt.plot(x[1:], y, label='N={}k'.format(N//1000))
    pass
plt.legend()
plt.xlim([-5, 5])
# Out:
# 1200000
# 600000
# 1000000
# 400000
# 800000
# (-5, 5)

# %%
one_by_nu
# Out:
# 0.5177072777685714

# %%
one_by_nu
# Out:
# 0.5161847779791164
